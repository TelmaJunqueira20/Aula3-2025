# %% [markdown]
# # Week 2 — Extra exercises: Titanic filters
#
# Practise the same filtering operations introduced in Week 2: comparisons, conditions combined with `&` and `|`, and row filtering with column selection using `loc`.
#
# Run the setup cell, then complete the exercises in order. Each exercise is independent: start from the original `df_titanic` every time. Display the matching rows; when specific columns are requested, show them in the listed order. Leave `df_titanic` unchanged.
#
# Use parentheses around each condition combined with `&` or `|`. All exercises can be solved with the operations above.
#
# ## Setup
#
# Use the `titanic.csv` supplied in `Week_2`. The cell below works when the notebook is run from `Week_2` or the repository root. In Colab, upload `titanic.csv` to the current session before running it.

# %%
from pathlib import Path
import pandas as pd

csv_path = Path("titanic.csv")
if not csv_path.is_file():
    csv_path = Path("Week_2") / "titanic.csv"
if not csv_path.is_file():
    raise FileNotFoundError("Place titanic.csv beside this notebook or run from the repository root.")

df_titanic = pd.read_csv(csv_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_6780/2503747736.py in <cell line: 0>()
#       6     csv_path = Path("Week_2") / "titanic.csv"
#       7 if not csv_path.is_file():
# ----> 8     raise FileNotFoundError("Place titanic.csv beside this notebook or run from the repository root.")
#       9
#      10 df_titanic = pd.read_csv(csv_path)
#
# FileNotFoundError: Place titanic.csv beside this notebook or run from the repository root.

# %% [markdown]
# ## Column reference
#
# | Column | Meaning / values |
# |---|---|
# | `Name` | Passenger name. |
# | `Sex` | `female` or `male`. |
# | `Age` | Age in years; some values are missing. |
# | `Pclass` | Ticket class: `1`, `2`, or `3`. |
# | `Survived` | `1` = survived; `0` = did not survive. |
# | `Fare` | Passenger fare. |
# | `Embarked` | `C` = Cherbourg, `Q` = Queenstown, `S` = Southampton. |
# | `SibSp` | Number of siblings and spouses aboard. |
# | `Parch` | Number of parents and children aboard. |
#
# For these exercises, **adult** means aged 18 or above. Missing ages do not satisfy the numeric age comparisons used here. Do not fill missing values.

# %% [markdown]
# ## Single conditions

# %% [markdown]
# ### F-01 — Second-class passengers
#
# Select all passengers who travelled in second class (`Pclass` equal to `2`).

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/usr/local/lib/python3.13/dist-packages/gradio/media_assets/data/titanic.csv")
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### F-02 — Passengers who did not survive
#
# Select all passengers whose `Survived` value is `0`.

# %%
df[df['Survived'] == 0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# ### F-03 — Passengers under 18
#
# Select all passengers younger than 18. Exclude passengers aged exactly 18.

# %%
df[df['Age'] < 18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %% [markdown]
# ### F-04 — Fares of at least 50
#
# Select all passengers whose `Fare` is greater than or equal to 50.

# %%
df[df['Fare'] >= 50]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 27            28         0       1
# 31            32         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### F-05 — Passengers embarking at Queenstown
#
# Select all passengers whose `Embarked` value is `Q`.

# %%
df[df['Embarked'] == 'Q']
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 5              6         0       3                      Moran, Mr. James
# 16            17         0       3                  Rice, Master. Eugene
# 22            23         1       3           McGowan, Miss. Anna "Annie"
# 28            29         1       3         O'Dwyer, Miss. Ellen "Nellie"
# 32            33         1       3              Glynn, Miss. Mary Agatha
# ..           ...       ...     ...                                   ...
# 790          791         0       3              Keane, Mr. Andrew "Andy"
# 825          826         0       3                       Flynn, Mr. John
# 828          829         1       3          McCormack, Mr. Thomas Joseph
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
# 890          891         0       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ## Combining conditions with AND

# %% [markdown]
# ### F-06 — Men in second class
#
# Select passengers whose `Sex` is `male` **and** whose `Pclass` is `2`.

# %%
passageiros_masculinos_class2 = df[(df['Sex'] == 'male') & (df['Pclass'] == 2)]
passageiros_masculinos_class2
# Out:
#      PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 17            18         1       2   Williams, Mr. Charles Eugene  male   NaN
# 20            21         0       2           Fynney, Mr. Joseph J  male  35.0
# 21            22         1       2          Beesley, Mr. Lawrence  male  34.0
# 33            34         0       2          Wheadon, Mr. Edward H  male  66.0
# 70            71         0       2     Jenkin, Mr. Stephen Curnow  male  32.0
# ..           ...       ...     ...                            ...   ...   ...
# 848          849         0       2              Harper, Rev. John  male  28.0
# 861          862         0       2    Giles, Mr. Frederick Edward  male  21.0
# 864          865         0       2         Gill, Mr. John William  male  24.0
# 883          884         0       2  Banfield, Mr. Frederick James  male  28.0
# 886          887         0       2          Montvila, Rev. Juozas  male  27.0
#
# ...

# %% [markdown]
# ### F-07 — Children who survived
#
# Select passengers younger than 10 **and** who survived.

# %%
# Your code here

# %% [markdown]
# ### F-08 — Fares within a range
#
# Select passengers who paid a fare from 10 to 30, **including both limits**. Use two comparisons combined with `&`.

# %%
# Your code here

# %% [markdown]
# ### F-09 — Adult passengers under 40
#
# Select passengers aged at least 18 **and** younger than 40.

# %%
# Your code here

# %% [markdown]
# ### F-10 — No recorded close relatives aboard
#
# Select passengers whose `SibSp` is `0` **and** whose `Parch` is `0`. This identifies passengers with no siblings, spouses, parents or children recorded aboard.

# %%
# Your code here

# %% [markdown]
# ## Combining conditions with OR

# %% [markdown]
# ### F-11 — First or second class
#
# Select passengers who travelled in first class **or** second class. Use two equality comparisons combined with `|`.

# %%
# Your code here

# %% [markdown]
# ### F-12 — Low or high fares
#
# Select passengers whose fare is less than 10 **or** greater than 100. Exclude fares equal to either boundary.

# %%
df[df['Fare'].between(10, 100, inclusive='neither')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### F-13 — Recorded close relatives aboard
#
# Select passengers whose `SibSp` is greater than `0` **or** whose `Parch` is greater than `0`.

# %%
# Your code here

# %% [markdown]
# ### F-14 — Young children or older adults
#
# Select passengers younger than 6 **or** aged 65 and above.

# %%
# Your code here

# %% [markdown]
# ## Filtering rows and selecting columns

# %% [markdown]
# ### F-15 — Women in second class
#
# Select female passengers in second class. Use `loc` to show only `Name`, `Sex`, and `Pclass`.

# %%
# Your code here

# %% [markdown]
# ### F-16 — Children embarking at Southampton
#
# Select passengers younger than 12 who embarked at Southampton (`S`). Use `loc` to show only `Name`, `Age`, and `Embarked`.

# %%
# Your code here

# %% [markdown]
# ### F-17 — Adult survivors with low fares
#
# Select passengers aged 18 or above who survived and paid a fare less than 15. Use `loc` to show only `Name`, `Age`, `Fare`, and `Survived`.

# %%
# Your code here

# %% [markdown]
# ## Mixed conditions: AND and OR

# %% [markdown]
# ### F-18 — Men embarking at two ports
#
# Select male passengers who embarked at Cherbourg (`C`) **or** Southampton (`S`). The condition for `Sex` must apply to both ports. Use `loc` to show only `Name`, `Sex`, and `Embarked`.

# %%
# Your code here

# %% [markdown]
# ### F-19 — Survivors in an age range and two classes
#
# Select passengers who satisfy **all** of the following:
#
# - they survived;
# - they were aged from 18 to 35, **including both limits**;
# - they travelled in second **or** third class.
#
# Store the combined condition in a variable, then use `loc` to show only `Name`, `Age`, `Pclass`, and `Survived`.

# %%
filter_aged_18_35 = df['Age'].between(18,35, inclusive='both')
filter_pclass_2 = df['Pclass'] == 2
filter_pclass_3 = df['Pclass'] == 3
df.loc[filter_aged_18_35 & filter_passager_survived & filter_pclass_2 & filter_pclass_3]

# %% [markdown]
# ### F-20 — Two passenger profiles
#
# Select passengers who match **either** of these profiles:
#
# - **Profile A:** female passengers in first class who survived;
# - **Profile B:** male passengers in third class who did not survive and were aged 18 or above.
#
# Create a condition for each profile, combine the two with `|`, then use `loc` to show only `Name`, `Sex`, `Age`, `Pclass`, and `Survived`.

# %%
# Your code here
filter_female = df['Sex'] == 'female'
filter_pclass_1 = df['Pclass'] == 1
filter_above_18 = df['Age'] >= 18
df[filter_female & filter_pclass_1].shape[0]
# Out:
# 94
